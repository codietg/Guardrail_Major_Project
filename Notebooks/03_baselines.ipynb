# %% [markdown]
# <a href="https://colab.research.google.com/github/codietg/Guardrail_Major_Project/blob/main/Notebooks/03_baselines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Purpose:**- Compare baseline models,	Run simple models for reference
